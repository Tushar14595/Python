# %% [markdown]
# In Python Everything is an object

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(5)
# Out:
# 5

# %%
print(17*14)
# Out:
# 238

# %%
print("single - line comment") # singleline comment
# Out:
# single - line comment

# %%
print("Hello" , 6 , 7, sep = " "  , end = "001")  # same line  print + seprator
print(" \"Good morning")
# Out:
# Hello 6 7001 "Good morning

# %%
print("hello I am good boy \n and also a good person")  # new line
# Out:
# hello I am good boy
#  and also a good person

# %%
print("hello \"I am good boy\"  and also a good person") #escape sequence
# Out:
# hello "I am good boy"  and also a good person

# %%
a = 12            # we cannot add a number with the string  +  data type check
b = 10
c = a + b
print(c)
print("The type of this variable is" , type(c))
# Out:
# 22
# The type of this variable is <class 'int'>

# %%
a = complex(8, 2) # complex number
print(a)
print(type(a))
# Out:
# (8+2j)
# <class 'complex'>

# %%
name = "Tushar"
age = 31
price = 25.11

print(type(name));
print(name);
print(type(age));
print(age);
print(type(price));
print(price);
# Out:
# <class 'str'>
# Tushar
# <class 'int'>
# 31
# <class 'float'>
# 25.11

# %%
a = 1000
b = 500
sum = a + b
print(type(sum))
print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/2625846332.py in <cell line: 0>()
#       2 b = 500
#       3 sum = a + b
# ----> 4 print(type(sum))
#       5 print(sum)
#
# TypeError: 'tuple' object is not callable

# %%
a = 1000
b = 500
diff = a - b
print(type(diff))
print(diff)
# Out:
# <class 'int'>
# 500

# %%
a =  eval (input("Enter a no."))
print(a*2)
type(a)
# Out:
# Enter a no.99999999999999999.6666666666666666666666666666666666666666666666666666
# 2e+17
# float

# %%
print("The teacher asked, \" Show me your homework.\" ")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/2844034918.py in <cell line: 0>()
# ----> 1 print("The teacher asked, \" Show me your homework.\" ")
#
# TypeError: 'tuple' object is not callable

# %%
name = "Tushar"
middleName = 'Kant'
lastName = "Behera"

print = ("Hello" , name , middleName , lastName)                  #strings

# %%
for letter in "help you online is great":
    if letter == 'e' or letter == 's':
        break
    print("current letter:", letter)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/2350534842.py in <cell line: 0>()
#       2     if letter == 'e' or letter == 's':
#       3         break
# ----> 4     print("current letter:", letter)
#
# TypeError: 'tuple' object is not callable

# %%
for letter in "help you online is great":
    if letter == 'e' or letter == 's':
        continue
    print("current letter:", letter)
# Out:
# current letter: h
# current letter: l
# current letter: p
# current letter:
# current letter: y
# current letter: o
# current letter: u
# current letter:
# current letter: o
# current letter: n
# current letter: l
# current letter: i
# current letter: n
# current letter:
# current letter: i
# current letter:
# current letter: g
# current letter: r
# current letter: a
# current letter: t

# %%
def display_number(number):
    if number == 2:
        pass
    else:
        print(number)

display_number(2)
display_number(3)
# Out:
# 3

# %%
list = [ 8 , 2 , 3  , [ 5.5 , 2.3 ]  , ["apple" , "mango"]] #mutable
print(list)
print(type(list))
# Out:
# [8, 2, 3, [5.5, 2.3], ['apple', 'mango']]
# <class 'list'>

# %%
tuple = ( 8 , 2 , 3  , ( 5.5 , 2.3 )  , ["apple" , "mango"])
print(tuple)
print(type(tuple))
# immutble
# Out:
# (8, 2, 3, (5.5, 2.3), ['apple', 'mango'])
# <class 'tuple'>

# %%
dict = { "name":"Sakshi" , "age":32 , "city":"Pune"}
print(dict)
print(type(dict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1538/98782789.py in <cell line: 0>()
#       1 dict = { "name":"Sakshi" , "age":32 , "city":"Pune"}
# ----> 2 print(dict)
#       3 print(type(dict))
#
# TypeError: 'tuple' object is not callable

# %%
a  = eval(input("Enter a number for Addition = "))
b  = eval(input("Enter b number for Addition = "))          #Addition
print(a + b)
print(type(a))
print(type(b))

a1 = eval(input("Enter a number for subtraction = "))          #Subtraction
b1 = eval(input("Enter b number for subtraction = "))
print(a1 - b1)
print(type(a1))
print(type(b1))


a2  = eval(input("Enter a number for Division = "))         #Divison
b2  = eval(input("Enter b number for Division = "))
print(a2 / b2)
print(type(a))
print(type(b))

a3  = eval(input("Enter a number for Multiplication = "))       #Multiplication
b3  = eval(input("Enter b number for Multiplication = "))
print(a3 * b3)
print(type(a3))
print(type(b3))

a4  = eval(input("Enter a number for Exponent = "))         #Exponent
b4  = eval(input("Enter b number for Exponent = "))
print(a4 ** b4)
print(type(a4))
print(type(b4))

a5  = eval(input("Enter a number for floor division = "))       #floor division
b5  = eval(input("Enter b number for floor division = "))
print(a5 // b5)
print(type(a5))
print(type(b5))

a6  = eval(input("Enter a number for modulous = "))         # Modulous
b6  = eval(input("Enter b number for modulous = "))
print(a6 % b6)
print(type(a6))
print(type(b6))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1538/1357383222.py in <cell line: 0>()
# ----> 1 a  = eval(input("Enter a number for Addition = "))
#       2 b  = eval(input("Enter b number for Addition = "))          #Addition
#       3 print(a + b)
#       4 print(type(a))
#       5 print(type(b))
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
a = "1"                           #Basic TypeCasting
b = "2"
print(int(a) + int(b))
# Out:
# 3

# %%
string = "15"
number = 7
string_number = int(string)  # throws an error if the string is not a valid integer Explicit TypeCasting

sum = number + string_number
print("The sum of both the numbers is: ", sum)
# Out:
# The sum of both the numbers is:  22

# %%
# Python automatically converts
# a to int
a = 7
print(type(a))
                                                                                              #Implicit TypeCasting
# Python automatically converts b
# to float
b = 3.0
print(type(b))

# Python automatically converts c
# to float as it is a float addition
c = a + b
print(c)
print(type(c))
